# %%
import pandas as pd

# %%
data=pd.read_csv("D:\\MACHINE LEARNING\\PROJECTS\\Music Reccomendation\\tcc_ceds_music.csv")
data.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
data.shape
# Out:
# (28372, 31)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# like/girls                  0
# sadness                     0
# feelings                    0
# danceability                0
# loudness                    0
# acousticness                0
# instrumentalness            0
# valence                     0
# energy                      0
# topic                       0
# age                         0
# ...

# %%
data.at[0,"artist_name"]
data.dtypes
# Out:
# Unnamed: 0                    int64
# artist_name                  object
# track_name                   object
# release_date                  int64
# genre                        object
# lyrics                       object
# len                           int64
# dating                      float64
# violence                    float64
# world/life                  float64
# night/time                  float64
# shake the audience          float64
# family/gospel               float64
# romantic                    float64
# communication               float64
# obscene                     float64
# music                       float64
# movement/places             float64
# light/visual perceptions    float64
# family/spiritual            float64
# like/girls                  float64
# sadness                     float64
# feelings                    float64
# danceability                float64
# loudness                    float64
# acousticness                float64
# ...

# %%
data["content"]=data["release_date"].astype(str)+data["genre"]+data["lyrics"]+data["len"].astype(str)+data["dating"].astype(str)+data["violence"].astype(str)+data["world/life"].astype(str)+data["night/time"].astype(str)+data["shake the audience"].astype(str)+data["family/gospel"].astype(str)+data["romantic"].astype(str)+data["communication"].astype(str)+data["obscene"].astype(str)+data["music"].astype(str)+data["movement/places"].astype(str)+data["music"].astype(str)+data["light/visual perceptions"].astype(str)+data["family/spiritual"].astype(str)+data["like/girls"].astype(str)+data["sadness"].astype(str)+data["feelings"].astype(str)+data["danceability"].astype(str)+data["loudness"].astype(str)+data["acousticness"].astype(str)+data["instrumentalness"].astype(str)+data["valence"].astype(str)+data["energy"].astype(str)+data["topic"]+data["age"].astype(str)

# %%
data.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                    int64
# artist_name                  object
# track_name                   object
# release_date                  int64
# genre                        object
# lyrics                       object
# len                           int64
# dating                      float64
# violence                    float64
# world/life                  float64
# night/time                  float64
# shake the audience          float64
# family/gospel               float64
# romantic                    float64
# communication               float64
# obscene                     float64
# music                       float64
# movement/places             float64
# light/visual perceptions    float64
# family/spiritual            float64
# like/girls                  float64
# sadness                     float64
# feelings                    float64
# danceability                float64
# loudness                    float64
# acousticness                float64
# ...

# %%
data1=pd.concat([data["artist_name"],data["track_name"],data["content"]],axis=1)

# %%
data
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
data1.shape
# Out:
# (28372, 3)

# %%
data1.head
# Out:
# <bound method NDFrame.head of                 artist_name                     track_name  \
# 0                    mukesh           mohabbat bhi jhoothi
# 1             frankie laine                      i believe
# 2               johnnie ray                            cry
# 3               pérez prado                       patricia
# 4      giorgos papadopoulos             apopse eida oneiro
# ...                     ...                            ...
# 28367               mack 10                10 million ways
# 28368                m.o.p.  ante up (robbin hoodz theory)
# 28369                  nine                  whutcha want?
# 28370            will smith                         switch
# 28371                 jeezy                         r.i.p.
#
#                                                  content
# 0      1950pophold time feel break feel untrue convin...
# 1      1950popbelieve drop rain fall grow believe dar...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform(data["content"])

# %%
vectors.shape
# Out:
# (28372, 577777)

# %%
print(vectors)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1851220 stored elements and shape (28372, 577777)>
#   Coords	Values
#   (0, 407468)	0.1273218020402114
#   (0, 569056)	0.04949127096540911
#   (0, 527082)	0.23202810887694794
#   (0, 513535)	0.13679720801342174
#   (0, 572257)	0.08269544024695356
#   (0, 518732)	0.08155983100324642
#   (0, 564129)	0.050264967316359425
#   (0, 573223)	0.052296596918524854
#   (0, 567645)	0.08013876165374921
#   (0, 570749)	0.17003454199079326
#   (0, 534899)	0.10508943475641756
#   (0, 536520)	0.2333286519294563
#   (0, 528630)	0.12610941998289324
#   (0, 549973)	0.12314626719754079
#   (0, 553185)	0.15210754405240373
#   (0, 565829)	0.19630596518933952
#   (0, 533657)	0.08889377899896549
#   (0, 573742)	0.09184196457895528
#   (0, 567857)	0.0910835403182574
#   (0, 556078)	0.1326713498551969
#   (0, 570714)	0.15022337624245635
#   (0, 541622)	0.1404271276326777
#   (0, 576023)	0.20834862589116288
#   (0, 507974)	0.17873654824758686
# ...

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors()
model.fit(vectors)
# Out:
# NearestNeighbors()

# %%
song_index = 33
distances, indices = model.kneighbors(vectors[song_index].reshape(1, -1))
print("Indices of similar songs:", indices.flatten())
# Out:
# Indices of similar songs: [   33  2939 18911  6310 22766]

# %%
for i in indices.flatten():
  print(data["track_name"].iloc[i])
# Out:
# raat andheri door savera
# the goonies 'r' good enough
# change on our ways
# interlude (that's love)
# bring it on home to me

# %%
import pickle
with open('knn_model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %%
with open('vectors.pkl','wb') as vector_file:
  pickle.dump(vectors,vector_file)

# %%
with open('data.pkl','wb') as data_file:
  pickle.dump(data1,data_file)
