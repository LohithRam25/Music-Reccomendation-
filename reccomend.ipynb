# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data=pd.read_csv("D:\\MACHINE LEARNING\\PROJECTS\\Music Reccomendation\\tcc_ceds_music.csv")

# %%
data.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# like/girls                  0
# sadness                     0
# feelings                    0
# danceability                0
# loudness                    0
# acousticness                0
# instrumentalness            0
# valence                     0
# energy                      0
# topic                       0
# age                         0
# ...

# %%
data.shape
# Out:
# (28372, 31)

# %%
data=data.drop(["age","energy","valence","instrumentalness","loudness"],axis=1)

# %%
data.shape
# Out:
# (28372, 26)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
#        'acousticness', 'topic'],
#       dtype='object')

# %%
data=data[["artist_name","track_name","release_date","genre","family/spiritual","sadness","romantic",'topic','dating', 'violence', 'world/life']]

# %%
data.shape
# Out:
# (28372, 11)

# %%
data.head()
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#    family/spiritual   sadness  romantic       topic    dating  violence  \
# 0          0.000598  0.380299  0.017104     sadness  0.000598  0.063746
# 1          0.051124  0.001284  0.001284  world/life  0.035537  0.096777
# 2          0.002770  0.002770  0.158564       music  0.002770  0.002770
# 3          0.001548  0.225889  0.411536    romantic  0.048249  0.001548
# 4          0.029755  0.068800  0.463430    romantic  0.001350  0.001350
#
#    world/life
# 0    0.000598
# 1    0.443435
# 2    0.002770
# 3    0.001548
# 4    0.417772

# %%
index_values=data.index

# %%
index_values
# Out:
# RangeIndex(start=0, stop=28372, step=1)

# %%
index_mukesh = data.index[data['artist_name'] == 'mukesh'].tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\FVIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'artist_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ...

# %%
index_mukesh
# Out:
# [0, 24, 33]

# %%
data.head()
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#    family/spiritual   sadness  romantic       topic    dating  violence  \
# 0          0.000598  0.380299  0.017104     sadness  0.000598  0.063746
# 1          0.051124  0.001284  0.001284  world/life  0.035537  0.096777
# 2          0.002770  0.002770  0.158564       music  0.002770  0.002770
# 3          0.001548  0.225889  0.411536    romantic  0.048249  0.001548
# 4          0.029755  0.068800  0.463430    romantic  0.001350  0.001350
#
#    world/life
# 0    0.000598
# 1    0.443435
# 2    0.002770
# 3    0.001548
# 4    0.417772

# %%
data.describe()
# Out:
#        release_date  family/spiritual       sadness      romantic  \
# count  28372.000000      28372.000000  28372.000000  28372.000000
# mean    1990.236888          0.024150      0.129389      0.048681
# std       18.487463          0.051025      0.181143      0.106095
# min     1950.000000          0.000284      0.000284      0.000284
# 25%     1975.000000          0.000957      0.001144      0.000975
# 50%     1991.000000          0.001645      0.005263      0.001754
# 75%     2007.000000          0.025498      0.235113      0.042301
# max     2019.000000          0.618073      0.981424      0.940789
#
#              dating      violence    world/life
# count  28372.000000  28372.000000  28372.000000
# mean       0.021112      0.118396      0.120973
# std        0.052370      0.178684      0.172200
# min        0.000291      0.000284      0.000291
# 25%        0.000923      0.001120      0.001170
# 50%        0.001462      0.002506      0.006579
# ...

# %%
data["overview"]=data["artist_name"]+" "+data["track_name"]+" "+data["genre"]

# %%
data.head()
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#    family/spiritual   sadness  romantic       topic    dating  violence  \
# 0          0.000598  0.380299  0.017104     sadness  0.000598  0.063746
# 1          0.051124  0.001284  0.001284  world/life  0.035537  0.096777
# 2          0.002770  0.002770  0.158564       music  0.002770  0.002770
# 3          0.001548  0.225889  0.411536    romantic  0.048249  0.001548
# 4          0.029755  0.068800  0.463430    romantic  0.001350  0.001350
#
#    world/life                                     overview
# 0    0.000598              mukesh mohabbat bhi jhoothi pop
# ...

# %%
data=data.drop(["artist_name","track_name","genre"],axis=1)

# %%
data.head()
# Out:
#    release_date  family/spiritual   sadness  romantic       topic    dating  \
# 0          1950          0.000598  0.380299  0.017104     sadness  0.000598
# 1          1950          0.051124  0.001284  0.001284  world/life  0.035537
# 2          1950          0.002770  0.002770  0.158564       music  0.002770
# 3          1950          0.001548  0.225889  0.411536    romantic  0.048249
# 4          1950          0.029755  0.068800  0.463430    romantic  0.001350
#
#    violence  world/life                                     overview
# 0  0.063746    0.000598              mukesh mohabbat bhi jhoothi pop
# 1  0.096777    0.443435                  frankie laine i believe pop
# 2  0.002770    0.002770                          johnnie ray cry pop
# 3  0.001548    0.001548                     pérez prado patricia pop
# 4  0.001350    0.417772  giorgos papadopoulos apopse eida oneiro pop

# %%
vectorizer=TfidfVectorizer()

# %%
feature_vectors=vectorizer.fit_transform(data["overview"])

# %%
print(feature_vectors)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 171259 stored elements and shape (28372, 14352)>
#   Coords	Values
#   (0, 8535)	0.47626007211345067
#   (0, 8352)	0.4901460443797733
#   (0, 1301)	0.5097172230707752
#   (0, 6533)	0.5097172230707752
#   (0, 9774)	0.11536855680551501
#   (1, 9774)	0.18442616674381904
#   (1, 4769)	0.5649249939399976
#   (1, 7053)	0.6298007734648435
#   (1, 1216)	0.5001976869050472
#   (2, 9774)	0.18596312016585603
#   (2, 6574)	0.6822092393400224
#   (2, 10255)	0.48214833738308693
#   (2, 3043)	0.5172439003565072
#   (3, 9774)	0.12957485938200777
#   (3, 10063)	0.5724829999851911
#   (3, 9840)	0.5724829999851911
#   (3, 9395)	0.5724829999851911
#   (4, 9774)	0.10070699108895978
#   (4, 5118)	0.44494001886677
#   (4, 9295)	0.44494001886677
#   (4, 647)	0.44494001886677
#   (4, 3976)	0.44494001886677
#   (4, 9047)	0.44494001886677
#   (5, 9774)	0.07751038790567216
#   (5, 10255)	0.20096191451997156
#   :	:
# ...

# %%
data.head()
# Out:
#    release_date  family/spiritual   sadness  romantic       topic    dating  \
# 0          1950          0.000598  0.380299  0.017104     sadness  0.000598
# 1          1950          0.051124  0.001284  0.001284  world/life  0.035537
# 2          1950          0.002770  0.002770  0.158564       music  0.002770
# 3          1950          0.001548  0.225889  0.411536    romantic  0.048249
# 4          1950          0.029755  0.068800  0.463430    romantic  0.001350
#
#    violence  world/life                                     overview
# 0  0.063746    0.000598              mukesh mohabbat bhi jhoothi pop
# 1  0.096777    0.443435                  frankie laine i believe pop
# 2  0.002770    0.002770                          johnnie ray cry pop
# 3  0.001548    0.001548                     pérez prado patricia pop
# 4  0.001350    0.417772  giorgos papadopoulos apopse eida oneiro pop

# %%
data["overview"]=data["overview"]+" "+data["topic"]

# %%
data=data.drop("topic",axis=1)

# %%
data.head()
# Out:
#    release_date  family/spiritual   sadness  romantic    dating  violence  \
# 0          1950          0.000598  0.380299  0.017104  0.000598  0.063746
# 1          1950          0.051124  0.001284  0.001284  0.035537  0.096777
# 2          1950          0.002770  0.002770  0.158564  0.002770  0.002770
# 3          1950          0.001548  0.225889  0.411536  0.048249  0.001548
# 4          1950          0.029755  0.068800  0.463430  0.001350  0.001350
#
#    world/life                                           overview
# 0    0.000598            mukesh mohabbat bhi jhoothi pop sadness
# 1    0.443435             frankie laine i believe pop world/life
# 2    0.002770                          johnnie ray cry pop music
# 3    0.001548                  pérez prado patricia pop romantic
# 4    0.417772  giorgos papadopoulos apopse eida oneiro pop ro...

# %%
feature_vectors
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 171259 stored elements and shape (28372, 14352)>

# %%
data.isnull().sum()
# Out:
# release_date        0
# family/spiritual    0
# sadness             0
# romantic            0
# dating              0
# violence            0
# world/life          0
# overview            0
# dtype: int64

# %%
feature_matrix=feature_vectors.todense()

# %%
matrix=pd.DataFrame(feature_matrix)
